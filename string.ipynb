# %%
age = 20
name='홍길동'
print('이름은 %s 나이는 %d'%(name,age))
print('이름은 %s 나이는 %5d'%(name,age))
print('이름은 %s 나이는 %05d'%(name,age))
print('pi=%f'%3.141592)
print('pi=%5f'%3.141592)
print('pi=%.2f'%3.141592)
# Out:
# 이름은 홍길동 나이는 20
# 이름은 홍길동 나이는    20
# 이름은 홍길동 나이는 00020
# pi=3.141592
# pi=3.141592
# pi=3.14
