# %%
print(2+4)
# Out:
# 6

# %%
print(5//3)
# Out:
# 1

# %%
num=3
print(num+5)
# Out:
# 8

# %%
num1=5 
num2=6
print(num1+num2)
# Out:
# 11

# %%
print(5**2)
# Out:
# 25

# %%
print(5**3)
# Out:
# 125

# %%
print(20%3)
# Out:
# 2

# %%
print('Hello'+'World!')
#print('Hello'-'World!)
#print('Hello'*'World')
print('Hello'*2)
# Out:
# HelloWorld!
# HelloHello

# %%
print(True and True)
# Out:
# True

# %%
print(not False)
# Out:
# True

# %%
num1=3
num2=5
print(not (num1>num2))
print(num1==num2)
# Out:
# True
# False
